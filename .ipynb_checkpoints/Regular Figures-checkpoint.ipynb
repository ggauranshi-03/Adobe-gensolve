# %%
import numpy as np

# %%
def read_csv(csv_path):
    np_path_XYs = np.genfromtxt(csv_path, delimiter=',')
    path_XYs = []
    for i in np.unique(np_path_XYs[:, 0]):
        npXYs = np_path_XYs[np_path_XYs[:, 0] == i][:, 1:]
        XYs = []
        for j in np.unique(npXYs[:, 0]):
            XY = npXYs[npXYs[:, 0] == j][:, 1:]
            XYs.append(XY)
        path_XYs.append(XYs)
    return path_XYs

# %%
read_csv('../Adobe GenSolve/problems/problems/isolated.csv')
# Out:
# [[array([[109.14299774, 125.58000183],
#          [110.15747833, 125.49578094],
#          [111.17194366, 125.40398407],
#          [112.18638611, 125.30522156],
#          [113.20079041, 125.20011139],
#          [114.21517181, 125.08926392],
#          [115.22950745, 124.97328949],
#          [116.2437973 , 124.85279083],
#          [117.25804138, 124.72838593],
#          [118.27222443, 124.60068512],
#          [119.28635406, 124.47029877],
#          [120.30041504, 124.33782959],
#          [121.31440735, 124.2039032 ],
#          [122.32831573, 124.06912231],
#          [123.34214783, 123.93410492],
#          [124.355896  , 123.79945374],
#          [125.36954498, 123.66577911],
#          [126.38310242, 123.53369141],
#          [127.39655304, 123.40380859],
#          [128.40989685, 123.27674103],
#          [129.42312622, 123.15309143],
#          [130.43623352, 123.03347778],
#          [131.44923401, 122.91851044],
#          [132.46208191, 122.80879974],
# ...

# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %% [markdown]
# ## Original shapes

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to read CSV file and parse polyline data
def read_csv(csv_path):
    np_path_XYs = np.genfromtxt(csv_path, delimiter=',')
    path_XYs = []
    for i in np.unique(np_path_XYs[:, 0]):
        npXYs = np_path_XYs[np_path_XYs[:, 0] == i][:, 1:]
        XYs = []
        for j in np.unique(npXYs[:, 0]):
            XY = npXYs[npXYs[:, 0] == j][:, 1:]
            XYs.append(XY)
        path_XYs.append(XYs)
    return path_XYs

# Function to plot original shapes
def plot(paths_XYs):
    colours = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    fig, ax = plt.subplots(tight_layout=True, figsize=(8, 8))
    for i, XYs in enumerate(paths_XYs):
        c = colours[i % len(colours)]
        for XY in XYs:
            ax.plot(XY[:, 0], XY[:, 1], c=c, linewidth=2)
    ax.set_aspect('equal')
    plt.show()

# Main function to execute the algorithm
def main():
    csv_path = '../Adobe GenSolve/problems/problems/isolated.csv'  # Update with actual CSV file path
    path_XYs = read_csv(csv_path)
    plot(path_XYs)

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Code for plotting shapes

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data (as provided)
shapes = [
    np.array([
       [ 66.61934662, 185.01887512],
       [ 66.67108917, 184.03643799],
       [ 66.73768616, 183.05407715],
       [ 66.81899261, 182.07200623],
       [ 66.91485596, 181.09039307],
       [ 67.02513885, 180.10946655],
       [ 67.14968109, 179.12939453],
       [ 67.28833008, 178.15039062],
       [ 67.44094849, 177.17263794],
       [ 67.60738373, 176.19633484],
       [ 67.78749084, 175.22166443],
       [ 67.98110962, 174.24884033],
       [ 68.18809509, 173.27806091],
       [ 68.40830231, 172.30949402],
       [ 68.64157867, 171.34335327],
       [ 68.88777924, 170.37983704],
       [ 69.1467514 , 169.41912842],
       [ 69.41835022, 168.46144104],
       [ 69.70241547, 167.50694275],
       [ 69.99881744, 166.55584717],
       [ 70.30738831, 165.6083374 ],
       [ 70.62799072, 164.66462708],
       [ 70.96046448, 163.72489929],
       [ 71.30467224, 162.78933716],
       [ 71.66046906, 161.8581543 ],
       [ 72.02768707, 160.93154907],
       [ 72.40618896, 160.00968933],
       [ 72.79582977, 159.09280396],
       [ 73.19644928, 158.18106079],
       [ 73.60791016, 157.2746582 ],
       [ 74.03005219, 156.37380981],
       [ 74.46273804, 155.47869873],
       [ 74.9058075 , 154.58950806],
       [ 75.3591156 , 153.70645142],
       [ 75.8225174 , 152.82972717],
       [ 76.29586029, 151.95950317],
       [ 76.77899933, 151.09599304],
       [ 77.28591919, 150.21913147],
       [ 77.80758667, 149.34925842],
       [ 78.34383392, 148.48681641],
       [ 78.89452362, 147.63224792],
       [ 79.45948792, 146.786026  ],
       [ 80.03858948, 145.94859314],
       [ 80.63166046, 145.12039185],
       [ 81.23855591, 144.30186462],
       [ 81.85912323, 143.49346924],
       [ 70.24795532, 208.18199158],
       [ 69.8730011 , 207.19000244],
       [ 69.54187012, 206.25941467],
       [ 69.22902679, 205.32443237],
       [ 68.93431854, 204.38523865],
       [ 68.6576004 , 203.44204712],
       [ 68.39871216, 202.49502563],
       [ 68.15752411, 201.54440308],
       [ 67.93386841, 200.59034729],
       [ 67.72760773, 199.6330719 ],
       [ 67.53858948, 198.67274475],
       [ 67.3666687 , 197.70959473],
       [ 67.21168518, 196.74378967],
       [ 67.07350159, 195.77554321],
       [ 66.9519577 , 194.80503845],
       [ 66.8469162 , 193.83247375],
       [ 66.75822449, 192.85804749],
       [ 66.68572998, 191.88194275],
       [ 66.62928772, 190.90437317],
       [ 66.58874512, 189.92552185],
       [ 66.56395721, 188.9455719 ],
       [ 66.55477142, 187.9647522 ],
       [ 66.56104279, 186.98323059],
       [ 66.58261871, 186.00120544]

    ])
]

# Function to plot the shapes
def plot_shapes(shapes):
    colours = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    fig, ax = plt.subplots(tight_layout=True, figsize=(8, 8))
    
    for i, shape in enumerate(shapes):
        c = colours[i % len(colours)]
        ax.plot(shape[:, 0], shape[:, 1], c=c, linewidth=2)
    
    ax.set_aspect('equal')
    plt.show()

# Plot the shapes
plot_shapes(shapes)

# %% [markdown]
# ## Expected result

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to read CSV file and parse polyline data
def read_csv(csv_path):
    np_path_XYs = np.genfromtxt(csv_path, delimiter=',')
    path_XYs = []
    for i in np.unique(np_path_XYs[:, 0]):
        npXYs = np_path_XYs[np_path_XYs[:, 0] == i][:, 1:]
        XYs = []
        for j in np.unique(npXYs[:, 0]):
            XY = npXYs[npXYs[:, 0] == j][:, 1:]
            XYs.append(XY)
        path_XYs.append(XYs)
    return path_XYs

# Function to plot original shapes
def plot(paths_XYs):
    colours = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    fig, ax = plt.subplots(tight_layout=True, figsize=(8, 8))
    for i, XYs in enumerate(paths_XYs):
        c = colours[i % len(colours)]
        for XY in XYs:
            ax.plot(XY[:, 0], XY[:, 1], c=c, linewidth=2)
    ax.set_aspect('equal')
    plt.show()

# Main function to execute the algorithm
def main():
    csv_path = '../Adobe GenSolve/problems/problems/isolated_sol.csv'  # Update with actual CSV file path
    path_XYs = read_csv(csv_path)
    plot(path_XYs)

if __name__ == "__main__":
    main()

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 11.0/11.0 MB 5.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 301.8/301.8 kB 6.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Detect and plot only circle

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import least_squares

def read_csv(csv_path):
    np_path_XYs = np.genfromtxt(csv_path, delimiter=',')
    path_XYs = []
    for i in np.unique(np_path_XYs[:, 0]):
        npXYs = np_path_XYs[np_path_XYs[:, 0] == i][:, 1:]
        path_XYs.append(npXYs)
    return path_XYs

def calc_R(xc, yc, x, y):
    return np.sqrt((x - xc)**2 + (y - yc)**2)

def residuals(c, x, y):
    Ri = calc_R(*c, x, y)
    return Ri - Ri.mean()

def fit_circle(XY):
    x = XY[:, 0]
    y = XY[:, 1]
    x_m = np.mean(x)
    y_m = np.mean(y)
    center_estimate = x_m, y_m
    result = least_squares(residuals, center_estimate, args=(x, y))
    xc, yc = result.x
    Ri = calc_R(xc, yc, x, y)
    R = Ri.mean()
    return xc, yc, R, result.cost

def detect_circles(csv_path, threshold=1e-2):
    path_XYs = read_csv(csv_path)
    circles = []
    for XY in path_XYs:
        xc, yc, R, residual = fit_circle(XY)
        if residual < threshold:
            circles.append((xc, yc, R, XY))
    return circles

def main():
    csv_path = '../Adobe GenSolve/problems/problems/isolated.csv'
    circles = detect_circles(csv_path)
    
    for xc, yc, R, XY in circles:
        print(f"Circle found with center: ({xc}, {yc}) and radius: {R}")
        print("Points on the circle:")
        for point in XY:
            print(f"{point},")
        print("----")

if __name__ == "__main__":
    main()
# Out:
# Circle found with center: (1084875.0936507087, 191.26668043055136) and radius: 1084875.0942264379
# Points on the circle:
# [  0.         140.84300232  11.85200024],
# [  0.         141.45674133  12.43616676],
# [  0.         142.09480286  13.01455879],
# [  0.         142.75631714  13.58733368],
# [  0.         143.44049072  14.15464687],
# [  0.         144.14648438  14.71665382],
# [  0.         144.8734436   15.27351189],
# [  0.         145.62057495  15.82537556],
# [  0.         146.38702393  16.37240219],
# [  0.         147.17196655  16.91474724],
# [  0.         147.97457886  17.45256615],
# [  0.         148.79402161  17.98601723],
# [  0.         149.62945557  18.51525307],
# [  0.         150.48007202  19.04043198],
# [  0.         151.34503174  19.56171036],
# [  0.         152.22351074  20.0792408 ],
# [  0.         153.1146698   20.59318352],
# [  0.         154.01766968  21.10369301],
# [  0.         154.93170166  21.61092567],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import least_squares

def read_csv(csv_path):
    np_path_XYs = np.genfromtxt(csv_path, delimiter=',')
    path_XYs = []
    for i in np.unique(np_path_XYs[:, 0]):
        npXYs = np_path_XYs[np_path_XYs[:, 0] == i][:, 1:]
        path_XYs.append(npXYs)
    return path_XYs

def calc_R(xc, yc, x, y):
    return np.sqrt((x - xc)**2 + (y - yc)**2)

def residuals(c, x, y):
    Ri = calc_R(*c, x, y)
    return Ri - Ri.mean()

def fit_circle(XY):
    x = XY[:, 0]
    y = XY[:, 1]
    x_m = np.mean(x)
    y_m = np.mean(y)
    center_estimate = x_m, y_m
    result = least_squares(residuals, center_estimate, args=(x, y))
    xc, yc = result.x
    Ri = calc_R(xc, yc, x, y)
    R = Ri.mean()
    return xc, yc, R, result.cost

def detect_circles(csv_path, threshold=1e-2):
    path_XYs = read_csv(csv_path)
    circles = []
    for XY in path_XYs:
        xc, yc, R, residual = fit_circle(XY)
        if residual < threshold:
            circles.append((xc, yc, R, XY))
    return circles

def plot_circle(xc, yc, R, XY):
    theta = np.linspace(0, 2*np.pi, 100)
    x_circle = xc + R * np.cos(theta)
    y_circle = yc + R * np.sin(theta)

    plt.figure()
    plt.plot(XY[:, 0], XY[:, 1], 'bo', label='Data Points')
    plt.plot(x_circle, y_circle, 'r-', label='Fitted Circle')
    plt.scatter(xc, yc, color='red', label='Circle Center')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Detected Circle')
    plt.legend()
    plt.show()

def main():
    csv_path = '../Adobe GenSolve/problems/problems/isolated.csv'
    circles = detect_circles(csv_path)
    
    for xc, yc, R, XY in circles:
        print(f"Circle found with center: ({xc}, {yc}) and radius: {R}")
        print("Points on the circle:")
        for point in XY:
            print(f"{point},")
        print("----")
        plot_circle(xc, yc, R, XY)

if __name__ == "__main__":
    main()
# Out:
# Circle found with center: (1084875.0936507087, 191.26668043055136) and radius: 1084875.0942264379
# Points on the circle:
# [  0.         140.84300232  11.85200024],
# [  0.         141.45674133  12.43616676],
# [  0.         142.09480286  13.01455879],
# [  0.         142.75631714  13.58733368],
# [  0.         143.44049072  14.15464687],
# [  0.         144.14648438  14.71665382],
# [  0.         144.8734436   15.27351189],
# [  0.         145.62057495  15.82537556],
# [  0.         146.38702393  16.37240219],
# [  0.         147.17196655  16.91474724],
# [  0.         147.97457886  17.45256615],
# [  0.         148.79402161  17.98601723],
# [  0.         149.62945557  18.51525307],
# [  0.         150.48007202  19.04043198],
# [  0.         151.34503174  19.56171036],
# [  0.         152.22351074  20.0792408 ],
# [  0.         153.1146698   20.59318352],
# [  0.         154.01766968  21.10369301],
# [  0.         154.93170166  21.61092567],
# ...
